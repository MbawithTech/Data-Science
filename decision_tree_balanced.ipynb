# %%
import numpy as np

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("sales_data.csv")

# %%
#Good_by_bad_ratio
ratings_ratio = []

for row in df.values:
  if (row[4] + row[5] == 0):
    if (row[7] + row[8] == 0):
      ratings_ratio.append(0.0)
    else:
      ratings_ratio.append(-9999)
  
  else:
    ratings_ratio.append((int(row[7])+int(row[8])) / (int(row[4]) + int(row[5])))

# %%
for index in range(len(ratings_ratio)):
  if ratings_ratio[index] == -9999:
    ratings_ratio[index] = max(ratings_ratio)
    ratings_ratio[index] = round(ratings_ratio[index], 3)
  else:
    ratings_ratio[index] = round(ratings_ratio[index], 3)

# %%
df["Good_by_bad_ratings"] = ratings_ratio

# %%
df_new = df.drop(labels=["1_Star_Rating", "2_Star_Rating", "3_Star_Rating", "4_Star_Rating", "5_Star_Rating", "Units_sold>1000"], axis=1)

# %%
df.head()
# Out:
#    Page_traffic  Unit_price  Units_sold    Segment  1_Star_Rating  \
# 0        5835.0   22.214389        2071   Skincare           99.0
# 1        1881.0   11.870778         681   Skincare          118.0
# 2        2477.0   27.645714         875     Makeup          108.0
# 3        4087.0   16.896848        1396     Makeup           82.0
# 4        1446.0   16.357664         822  Hair Care           29.0
#
#    2_Star_Rating  3_Star_Rating  4_Star_Rating  5_Star_Rating  Image_Count  \
# 0           72.0          194.0          453.0         3272.0          6.0
# 1           73.0          200.0          430.0         3084.0          9.0
# 2           85.0          232.0          511.0         3402.0         10.0
# 3           64.0          167.0          303.0         2058.0          5.0
# 4           24.0           88.0          200.0         1221.0          0.0
#
#    ...  Online_Clicks  Online_Cost  Online_Impressions  num_unique_campaigns  \
# ...

# %%
df1 = df.drop(labels=["1_Star_Rating", "2_Star_Rating", "3_Star_Rating", "4_Star_Rating", "5_Star_Rating", "Units_sold"], axis=1)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df1[["Segment"]] = df1[["Segment"]].apply(LabelEncoder().fit_transform)

# %%
df1.head()
# Out:
#    Page_traffic  Unit_price  Segment  Image_Count  Bullet_Count  Title_Count  \
# 0        5835.0   22.214389        2          6.0           6.0         89.0
# 1        1881.0   11.870778        2          9.0           8.0        126.0
# 2        2477.0   27.645714        1         10.0           7.0        152.0
# 3        4087.0   16.896848        1          5.0           7.0        117.0
# 4        1446.0   16.357664        0          0.0           8.0        165.0
#
#    Description_Length  num_unique_Search_Terms  Organic Search Rank  \
# 0               141.0                      3.0                  3.0
# 1               149.0                     13.0                 16.0
# 2               186.0                      4.0                 20.0
# 3               209.0                      7.0                 20.0
# 4               158.0                      4.0                 16.0
#
#    Num_of_Promotions  ...  Online_Clicks  Online_Cost  Online_Impressions  \
# ...

# %%
X = df1.drop(columns=["Units_sold>1000"], axis=1)

# %%
y = df1["Units_sold>1000"]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=6)

# %%
y_train.value_counts(normalize=True)
# Out:
# Units_sold>1000
# 1    0.598137
# 0    0.401863
# Name: proportion, dtype: float64

# %%
y_test.value_counts(normalize=True)
# Out:
# Units_sold>1000
# 1    0.614261
# 0    0.385739
# Name: proportion, dtype: float64

# %%
#Stratified Splitting
X_train_st, X_test_st, y_train_st, y_test_st = train_test_split(X, y, test_size=0.3, stratify=y, random_state=6)

# %%
print(y_train_st.value_counts(normalize=True))
print(y_test_st.value_counts(normalize=True))
# Out:
# Units_sold>1000
# 1    0.60294
# 0    0.39706
# Name: proportion, dtype: float64
# Units_sold>1000
# 1    0.603056
# 0    0.396944
# Name: proportion, dtype: float64

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
DT_model = DecisionTreeClassifier(max_depth=11, min_samples_leaf=6, random_state=42, class_weight="balanced")

# %%
DT_model.fit(X_train_st, y_train_st)
# Out:
# DecisionTreeClassifier(class_weight='balanced', max_depth=11,
#                        min_samples_leaf=6, random_state=42)

# %%
from sklearn.metrics import f1_score, classification_report

# %%
y_train_pred_st = DT_model.predict(X_train_st)
y_pred_st = DT_model.predict(X_test_st)

# %%
f1_score(y_train_st, y_train_pred_st)
# Out:
# 0.8872834139472234

# %%
f1_score(y_test_st, y_pred_st)
# Out:
# 0.8272221429590526

# %%
print(classification_report(y_train_st, y_train_pred_st))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.85      0.83      5456
#            1       0.90      0.87      0.89      8285
#
#     accuracy                           0.87     13741
#    macro avg       0.86      0.86      0.86     13741
# weighted avg       0.87      0.87      0.87     13741

# %%
print(classification_report(y_test_st, y_pred_st))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.76      0.75      2338
#            1       0.84      0.82      0.83      3552
#
#     accuracy                           0.79      5890
#    macro avg       0.79      0.79      0.79      5890
# weighted avg       0.80      0.79      0.80      5890

# %% [markdown]
# Undersampling and Oversampling

# %%
# !pip install imblearn
# Out:
# ...
#      -------------------------------------- 258.3/258.3 kB 5.3 MB/s eta 0:00:00
# ...
# [notice] A new release of pip available: 22.3.1 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from imblearn.under_sampling import RandomUnderSampler

# %%
sampler = RandomUnderSampler(random_state=42)

# %%
X_train_rus, y_train_rus = sampler.fit_resample(X_train, y_train)

# %%
y_train_rus.value_counts(normalize=True)
# Out:
# Units_sold>1000
# 0    0.5
# 1    0.5
# Name: proportion, dtype: float64

# %%
DT_model_new = DecisionTreeClassifier(max_depth=11, min_samples_leaf=6, random_state=42)

# %%
DT_model_new.fit(X_train_rus, y_train_rus)
# Out:
# DecisionTreeClassifier(max_depth=11, min_samples_leaf=6, random_state=42)

# %%
y_train_pred_rus = DT_model_new.predict(X_train_rus)
y_pred_rus = DT_model_new.predict(X_test)

# %%
print(classification_report(y_train_rus, y_train_pred_rus))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.86      0.86      5522
#            1       0.86      0.87      0.87      5522
#
#     accuracy                           0.87     11044
#    macro avg       0.87      0.87      0.87     11044
# weighted avg       0.87      0.87      0.87     11044

# %%
print(classification_report(y_test, y_pred_rus))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      0.80      0.75      2272
#            1       0.86      0.79      0.82      3618
#
#     accuracy                           0.79      5890
#    macro avg       0.78      0.79      0.79      5890
# weighted avg       0.80      0.79      0.79      5890

# %% [markdown]
# Oversampling

# %%
from imblearn.over_sampling import RandomOverSampler

# %%
rs_sampler = RandomOverSampler()

# %%
X_train_ros, y_train_ros = rs_sampler.fit_resample(X_train, y_train)

# %%
DT_model_new.fit(X_train_ros, y_train_ros)
# Out:
# DecisionTreeClassifier(max_depth=11, min_samples_leaf=6, random_state=42)

# %%
y_train_pred_ros = DT_model_new.predict(X_train_ros)
y_pred_ros = DT_model_new.predict(X_test)

# %%
print(classification_report(y_train_ros, y_train_pred_ros))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.86      0.87      8219
#            1       0.86      0.87      0.87      8219
#
#     accuracy                           0.87     16438
#    macro avg       0.87      0.87      0.87     16438
# weighted avg       0.87      0.87      0.87     16438

# %%
print(classification_report(y_test, y_pred_ros))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.78      0.74      2272
#            1       0.85      0.80      0.83      3618
#
#     accuracy                           0.79      5890
#    macro avg       0.78      0.79      0.78      5890
# weighted avg       0.80      0.79      0.79      5890

# %%
from imblearn.over_sampling import SMOTE

# %%
smote = SMOTE(random_state=42)

# %%
X_train_smo, y_train_smo = smote.fit_resample(X_train, y_train)

# %%
DT_model_new.fit(X_train_smo, y_train_smo)
# Out:
# DecisionTreeClassifier(max_depth=11, min_samples_leaf=6, random_state=42)

# %%
y_train_smo_pred = DT_model_new.predict(X_train_smo)
y_pred_smo = DT_model_new.predict(X_test)

# %%
print(classification_report(y_train_smo, y_train_smo_pred))
print(classification_report(y_test, y_pred_smo))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.86      0.86      8219
#            1       0.86      0.86      0.86      8219
#
#     accuracy                           0.86     16438
#    macro avg       0.86      0.86      0.86     16438
# weighted avg       0.86      0.86      0.86     16438
#
#               precision    recall  f1-score   support
#
#            0       0.72      0.79      0.75      2272
#            1       0.86      0.81      0.83      3618
#
#     accuracy                           0.80      5890
#    macro avg       0.79      0.80      0.79      5890
# weighted avg       0.80      0.80      0.80      5890
